# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.drop('customerID', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df.isnull().any().sum()
# Out:
# 0

# %%
df['Churn'].replace({"yes":1,"no":0},)
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
# Name: Churn, Length: 7032, dtype: object

# %%
df.head(-5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7033    Male              0      No         No      38          Yes
# 7034  Female              0      No         No      67          Yes
# 7035    Male              0      No         No      19          Yes
# 7036  Female              0      No         No      12           No
# 7037  Female              0      No         No      72          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 0     No phone service             DSL                   No
# ...

# %%
df['TotalCharges']=pd.to_numeric(df["TotalCharges"], errors='coerce')

# %%
df.isnull().any().sum()
# Out:
# 1

# %%
df.dropna(axis=0, inplace=True)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.corr('pearson')
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# SeniorCitizen        1.000000  0.015683        0.219874      0.102411
# tenure               0.015683  1.000000        0.246862      0.825880
# MonthlyCharges       0.219874  0.246862        1.000000      0.651065
# TotalCharges         0.102411  0.825880        0.651065      1.000000

# %%
df1=pd.get_dummies(df)

# %%
df1.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Female  \
# 0              0       1           29.85         29.85              1
# 1              0      34           56.95       1889.50              0
# 2              0       2           53.85        108.15              0
# 3              0      45           42.30       1840.75              0
# 4              0       2           70.70        151.65              1
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0            0           0            1              1               0  ...
# 1            1           1            0              1               0  ...
# 2            1           1            0              1               0  ...
# 3            1           1            0              1               0  ...
# 4            0           1            0              1               0  ...
#
#    Contract_One year  Contract_Two year  PaperlessBilling_No  \
# ...

# %%
df1["churn"]=df1["Churn_No"].astype(str)+df1["Churn_Yes"].astype(str)

# %%
df1.drop('Churn_No', axis=1, inplace=True)

# %%
df1.drop('Churn_Yes', axis=1, inplace=True)

# %%
df1.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Female  \
# 0              0       1           29.85         29.85              1
# 1              0      34           56.95       1889.50              0
# 2              0       2           53.85        108.15              0
# 3              0      45           42.30       1840.75              0
# 4              0       2           70.70        151.65              1
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0            0           0            1              1               0  ...
# 1            1           1            0              1               0  ...
# 2            1           1            0              1               0  ...
# 3            1           1            0              1               0  ...
# 4            0           1            0              1               0  ...
#
#    Contract_Month-to-month  Contract_One year  Contract_Two year  \
# ...

# %%
df1['churn'].replace({"01":1,"10":0})
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: churn, Length: 7032, dtype: int64

# %%
df1.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Female  \
# 0              0       1           29.85         29.85              1
# 1              0      34           56.95       1889.50              0
# 2              0       2           53.85        108.15              0
# 3              0      45           42.30       1840.75              0
# 4              0       2           70.70        151.65              1
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0            0           0            1              1               0  ...
# 1            1           1            0              1               0  ...
# 2            1           1            0              1               0  ...
# 3            1           1            0              1               0  ...
# 4            0           1            0              1               0  ...
#
#    Contract_Month-to-month  Contract_One year  Contract_Two year  \
# ...

# %%
x=df1.drop("churn",axis=1)
y=df1["churn"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
x_train , x_test, y_train, y_test= train_test_split(x,y)

# %%
log=LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred1=log.predict(x_test)

# %%
y_pred2=log.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_pred1,y_test)
# Out:
# 0.8083048919226393

# %%
accuracy_score(y_pred2,y_test)
# Out:
# 0.8083048919226393

# %%
rf.feature_importances_
# Out:
# array([0.02069881, 0.14234366, 0.13381625, 0.15048797, 0.01848315,
#        0.01760559, 0.01499435, 0.01390322, 0.01253855, 0.01271354,
#        0.00317586, 0.0029434 , 0.01289082, 0.0028463 , 0.0130918 ,
#        0.01225406, 0.02692415, 0.00311177, 0.03494981, 0.00348581,
#        0.01124602, 0.01974042, 0.00240675, 0.01245343, 0.01533318,
#        0.00230656, 0.01143108, 0.03045911, 0.00102481, 0.01044263,
#        0.0112064 , 0.00198557, 0.01219627, 0.01190832, 0.00309644,
#        0.01136887, 0.0463131 , 0.01229315, 0.02416013, 0.01465187,
#        0.01662033, 0.01272474, 0.01288458, 0.02677957, 0.01170779])

# %%
weight=pd.DataFrame(rf.feature_importances_,index=x.columns.values)

# %%
weight
# Out:
#                                                 0
# SeniorCitizen                            0.020699
# tenure                                   0.142344
# MonthlyCharges                           0.133816
# TotalCharges                             0.150488
# gender_Female                            0.018483
# gender_Male                              0.017606
# Partner_No                               0.014994
# Partner_Yes                              0.013903
# Dependents_No                            0.012539
# Dependents_Yes                           0.012714
# PhoneService_No                          0.003176
# PhoneService_Yes                         0.002943
# MultipleLines_No                         0.012891
# MultipleLines_No phone service           0.002846
# MultipleLines_Yes                        0.013092
# InternetService_DSL                      0.012254
# InternetService_Fiber optic              0.026924
# InternetService_No                       0.003112
# ...

# %%
import matplotlib.pyplot as mtp
import seaborn as sns

# %%
sns.countplot('gender',data=df,hue="Churn")
# Out:
# C:\Users\razzan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot('SeniorCitizen',data=df,hue="Churn")
# Out:
# C:\Users\razzan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='count'>

# %%
sns.kdeplot("MonthlyCharges",data=df)
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='Density'>

# %% [markdown]
# no churn when total charge and monthly chsrge are low

# %%
sns.kdeplot("TotalCharges",data=df)
# Out:
# <AxesSubplot:xlabel='TotalCharges', ylabel='Density'>
